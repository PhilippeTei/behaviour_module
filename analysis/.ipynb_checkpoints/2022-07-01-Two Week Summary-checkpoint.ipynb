# %%
import numpy as np
from behaviour import RegionalBehaviourModel
import covasim as cv

fname = '/home/andrew/dev/wble_proj/behaviour_module/tests/mr_pop.pop'

# Generate population
params_ca = dict(name = 'city_a', n=20000, com_contacts=20) # large city
params_cb = dict(name = 'city_b', n=10000, com_contacts=10) # medium city
params_cc = dict(name = 'city_c', n=5000,  com_contacts=10) # small city
pop_mod = RegionalBehaviourModel(None, *(params_ca, params_cb, params_cc))
pop_mod.save(fname)
# Out:
# BEHAVIOUR_MODULE
# BEHAVIOUR_MODULE
# BEHAVIOUR_MODULE
# '/home/andrew/dev/wble_proj/behaviour_module/tests/mr_pop.pop'

# %%
# Run the simulation. 

pop_mod = RegionalBehaviourModel.load(fname)
# Set defaults
pop_size = 35000
pop_type = 'behaviour_module'
n_days = 200

# Create parameter dictionary 
pars = dict(
    pop_size = pop_size,
    pop_type = pop_type, 
    n_days = n_days,
    rand_seed = 1)

sim = cv.Sim(pars=pars, people=pop_mod.total_popdict, multireg_pars = pop_mod.reg_pars)
sim.run(verbose=False)
# Out:
# Initializing sim with 35000 people for 200 days
# Sim(<no label>; 2020-03-01 to 2020-09-17; pop: 35000 behaviour_module; epi: 24143⚙, 87☠)

# %%
import matplotlib.pyplot as plt

# Plotting. 
rnames = sim.rnames
rsizes = sim.rsizes

x_axis = np.arange(0, sim.t+1)

for rname in rnames:
    plt.plot(x_axis, sim.results[f"{rname}_n_infectious"])
    
plt.plot(x_axis, sim.results["n_infectious"]) # cumulative
    
plt.xlabel("day")
plt.ylabel("number of infectious")
plt.title("multi-region simulation")
plt.legend(rnames + ["cumulative"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Now run a simulation with the same population, but the initial infections seeded differently.

it0_advanced_params = dict(
    uid_list = None,
    regs_to_infect = {'city_a':0, 'city_b': 0, 'city_c':20} # default is 20 in covasim.
)

pars = dict(
    pop_size = pop_size,
    pop_type = pop_type, 
    n_days = n_days,
    rand_seed = 1)

i_sim = cv.Sim(pars=pars, people=pop_mod.total_popdict,it0_advanced_params=it0_advanced_params,
             multireg_pars = pop_mod.reg_pars)
i_sim.run(verbose=False)
# Out:
# Initializing sim with 35000 people for 200 days
#   Running 2020-03-01 ( 0/200) (6.21 s)  ———————————————————— 0%
#   Running 2020-03-11 (10/200) (6.28 s)  •——————————————————— 5%
#   Running 2020-03-21 (20/200) (6.35 s)  ••—————————————————— 10%
#   Running 2020-03-31 (30/200) (6.42 s)  •••————————————————— 15%
#   Running 2020-04-10 (40/200) (6.51 s)  ••••———————————————— 20%
#   Running 2020-04-20 (50/200) (6.60 s)  •••••——————————————— 25%
#   Running 2020-04-30 (60/200) (6.69 s)  ••••••—————————————— 30%
#   Running 2020-05-10 (70/200) (6.80 s)  •••••••————————————— 35%
#   Running 2020-05-20 (80/200) (6.92 s)  ••••••••———————————— 40%
#   Running 2020-05-30 (90/200) (7.07 s)  •••••••••——————————— 45%
#   Running 2020-06-09 (100/200) (7.25 s)  ••••••••••—————————— 50%
#   Running 2020-06-19 (110/200) (7.43 s)  •••••••••••————————— 55%
#   Running 2020-06-29 (120/200) (7.62 s)  ••••••••••••———————— 60%
#   Running 2020-07-09 (130/200) (7.77 s)  •••••••••••••——————— 65%
#   Running 2020-07-19 (140/200) (7.92 s)  ••••••••••••••—————— 70%
#   Running 2020-07-29 (150/200) (8.05 s)  •••••••••••••••————— 75%
#   Running 2020-08-08 (160/200) (8.19 s)  ••••••••••••••••———— 80%
#   Running 2020-08-18 (170/200) (8.31 s)  •••••••••••••••••——— 85%
#   Running 2020-08-28 (180/200) (8.44 s)  ••••••••••••••••••—— 90%
#   Running 2020-09-07 (190/200) (8.54 s)  •••••••••••••••••••— 95%
#   Running 2020-09-17 (200/200) (8.65 s)  •••••••••••••••••••• 100%
#
# Simulation summary:
#        24,356 cumulative infections
#         3,774 cumulative reinfections
#        24,354 cumulative infectious
#        15,539 cumulative symptomatic cases
#         1,049 cumulative severe cases
#           290 cumulative critical cases
#        24,241 cumulative recoveries
#           100 cumulative deaths
#             0 cumulative tests
#             0 cumulative diagnoses
#             0 cumulative known deaths
#             0 cumulative quarantined people
#             0 cumulative vaccine doses
#             0 cumulative vaccinated people
# Sim(<no label>; 2020-03-01 to 2020-09-17; pop: 35000 behaviour_module; epi: 24356⚙, 100☠)

# %%
# Plotting. 
rnames = sim.rnames
rsizes = sim.rsizes

x_axis = np.arange(0, i_sim.t+1)

for rname in rnames:
    plt.plot(x_axis, i_sim.results[f"{rname}_n_infectious"])
    
plt.plot(x_axis, i_sim.results["n_infectious"]) # cumulative
    
plt.xlabel("day")
plt.ylabel("number of infectious")
plt.title("Multi-region simulation with all initial infections in city c")
plt.legend(rnames + ["cumulative"])
plt.show()

# %% [markdown]
# #### Superspreading behaviour ####

# %% [markdown]
# """
# Single-region.
# First, init two populations with superspreading enabled/disabled in com
# Plot their distributions of contacts. (Code already written)
#     - Histogram.
# Then run two sims which use the different pops.
# """

# %%
import numpy as np
import behaviour as bh
import covasim as cv
import matplotlib.pyplot as plt

pars = dict(n=20000, rand_seed=1)
pars_ss = dict(n=20000, rand_seed=1, com_dispersion=0.2)

pop = bh.BehaviourModel(pars)
pop_ss = bh.BehaviourModel(pars_ss)

# Extract list of community contacts for each sim.
# Out:
# BEHAVIOUR_MODULE
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_97877/2294109179.py in <module>
#       7 pars_ss = dict(n=20000, rand_seed=1, com_dispersion=0.2)
#       8
# ----> 9 pop = bh.BehaviourModel(pars)
#      10 pop_ss = bh.BehaviourModel(pars_ss)
#      11
#
# ~/dev/wble_proj/behaviour_module/behaviour/behaviour_model.py in __init__(self, pars)
#     193             # i.e. via regional_behaviour_model.py
#     194             log.debug('Generating a new population...')
# --> 195             self.generate() # updates self.popdict
#     196
#     197             # Add summaries post hoc  --- TBD: summaries during generation
#
# ~/dev/wble_proj/behaviour_module/behaviour/behaviour_model.py in generate(self)
#     599
#     600         # This needs to be placed here because additional structure (classroom-resolution for schools) is introduced in make_contacts.
# --> 601         self.consolidate_structures(self.structs)
#     602
#     603         # Change types
#
# ~/dev/wble_proj/behaviour_module/behaviour/behaviour_model.py in consolidate_structures(self, structs)
#     508                 self.ltcf_pars.with_facilities = False
#     509
# --> 510         self.set_layer_classes()
#     511         self.clean_up_layer_info()
#     512
#
# ~/dev/wble_proj/behaviour_module/behaviour/behaviour_model.py in set_layer_classes(self)
#     614
#     615         self.initialize_schools_list()
# --> 616         self.populate_schools(self.student_uid_lists, self.teacher_uid_lists,
#     617                               self.non_teaching_staff_uid_lists, self.age_by_uid,
#     618                               self.school_types, self.school_mixing_types)
#
# ~/dev/wble_proj/behaviour_module/behaviour/behaviour_model.py in populate_schools(self, student_lists, teacher_lists, non_teaching_staff_lists, age_by_uid, school_types, school_mixing_types)
#     859             school_mixing_types (list)      : list of the school mixing types
#     860         """
# --> 861         spsch.populate_schools(self, student_lists, teacher_lists, non_teaching_staff_lists, age_by_uid, school_types, school_mixing_types)
#     862         return
#     863
#
# ~/dev/wble_proj/behaviour_module/behaviour/schools.py in populate_schools(pop, student_lists, teacher_lists, non_teaching_staff_lists, age_by_uid, school_types, school_mixing_types)
#     413         non_teaching_staff = non_teaching_staff_lists[ns]
#     414         sc_type = school_types[ns]
# --> 415         school_mixing_type = school_mixing_types[ns]
#     416
#     417         kwargs = dict(scid=ns,
#
# IndexError: list index out of range
