# %%
import synthpops as sp

# %%
pop = sp.Pop.load('population1.pop')

# %%
pop.schools[0]
# Out:
# {'member_uids': array([], dtype=int64),
#  'scid': 0,
#  'sc_type': None,
#  'school_mixing_type': None,
#  'student_uids': array([  91,   83,   62,  127,   19,  132,  109,   97,   22,  129,   13,
#          339,  409,   30,  378,  471,  256,   12,  166,  453,  464,  168,
#          184,  487,  747,  626,  170,  242,   25,  268,  845,  299,  206,
#          213,  244,  650,  306,  348,    8,  892,  400,  373,  715,  604,
#          282,  679,  605,  557,  600,  740,  796,  956,  970,  475,  755,
#          837,  844,  978,  741,  798,   31, 1053,  900, 1220,  925,  945,
#         1121, 1188,  847, 1236,  950, 1010, 1068,  732,  976,   26,  807,
#         1199, 1082, 1242, 1364, 1265, 1094, 1187, 1201, 1437, 1290, 1304,
#         1230, 1630,  118, 1354, 1395, 1661,   48, 1511, 1264, 1426, 1695,
#         1508,   49, 1554, 1772, 1723, 1795, 1551, 1807, 1751, 1886, 1614,
#         1936,  895, 1943, 1773, 1804, 1896, 1968, 1813, 1789, 1905, 1869,
# ...
