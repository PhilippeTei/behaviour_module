# %% [markdown]
# #### Multi-region Worker-Mixing Test ####

# %%
import numpy as np
from behaviour import RegionalBehaviourModel

"""
Warning: hard-coded. Will break if you change the params. 
"""
params_ca = dict(name = 'toronto', n=20000, com_contacts=20) # large city
params_cb = dict(name = 'miss', n=10000, com_contacts=10) # medium city
params_cc = dict(name = 'milton', n=5000,  com_contacts=10) # small city

dests_a = {'miss':0.6, 'milton':0.4}
dests_b = {'toronto':0.9, 'milton':0.1}
dests_c = {'toronto':0.9, 'miss': 0.1}

params_work_mixing = dict(toronto = {"leaving":0.05, "dests":dests_a},
                          miss =    {"leaving":0.4, "dests":dests_b},
                          milton =  {"leaving":0.3, "dests":dests_c})

pop_mod = RegionalBehaviourModel(None, params_work_mixing, *(params_ca, params_cb, params_cc))
# Out:
# Covasim 3.1.2 (2022-01-16) — © 2020-2022 by IDM
# Community mixing parameters not given; initializing defaults...
# BEHAVIOUR_MODULE
# BEHAVIOUR_MODULE
# BEHAVIOUR_MODULE

# %%
pop_mod.regs['toronto'].structs.keys()
# Out:
# ['age_by_uid',
#  'fam_income_by_uid',
#  'homes_by_uids',
#  'homes_by_ages',
#  'student_uid_lists',
#  'student_age_lists',
#  'facilities',
#  'facilities_uid_lists',
#  'school_type_by_age',
#  'school_mixing_types',
#  'school_types',
#  'workplaces_by_industry_codes',
#  'teacher_uid_lists',
#  'non_teaching_staff_uid_lists',
#  'workplace_uid_lists',
#  'facilities_staff_uid_lists']

# %%
firms = pop_mod.regs['toronto'].structs.workplace_uid_lists
n_from_a = {}
n_from_b = {}
n_from_c = {}
for reg in pop_mod.regs:
    firms = pop_mod.regs[reg].structs.workplace_uid_lists
    n_from_a[reg] = []
    n_from_b[reg] = []
    n_from_c[reg] = []
    
    for firm in firms:
        n_from_a[reg].append(sum([i < 20000 for i in firm])) # identify origin of the agents based on their uid
        n_from_b[reg].append(sum([i >= 20000 and i < 30000 for i in firm]))
        n_from_c[reg].append(sum([i >= 30000 for i in firm]))

# %%
import matplotlib.pyplot as plt

# Create 3 subplots, for the 3 separate regions. 
fig, axs = plt.subplots(1,3,sharey=True)

regs = list(pop_mod.regs.keys())

for i_reg, reg in enumerate(pop_mod.regs):
    x_axis = np.arange(len(pop_mod.regs[reg].structs.workplace_uid_lists))
    axs[i_reg].plot(x_axis, n_from_a[reg])
    axs[i_reg].plot(x_axis, n_from_b[reg])
    axs[i_reg].plot(x_axis, n_from_c[reg])
    axs[i_reg].set_title(f"Workers of {reg}")
    axs[i_reg].set_xlabel("Company ID")
    axs[i_reg].set_ylabel("Number of workers")

plt.legend(regs)

plt.show()

# %%
#### Recreate the Matrix ####
# pop_mod.total_valid_workers["toronto"]

src_dest = {}
reg_list = list(pop_mod.regs.keys())

ranges = {"toronto":[0,20000], "miss": [20000,30000], "milton":[30000,35000]}
    
for src in pop_mod.regs:
    oregs = list(reg_list)
    oregs.remove(src)
    
    dest_counts = {oregs[0]:0, oregs[1]:0} # always only 2 other regs.

    for dest in oregs:
        # Count number of people from src city working in this other region. 
        wkplces = pop_mod.regs[dest].structs.workplace_uid_lists
        for wkplce in wkplces:
            for uid in wkplce:
                if uid > ranges[src][0] and uid < ranges[src][1]:
                    dest_counts[dest] += 1
        src_dest[src] = dest_counts
# go_to_come_from = {}
# reg_list = list(pop_mod.regs.keys())
# for dest in pop_mod.regs:
#     oregs = list(reg_list)
#     oregs.remove(dest)
    
#     ranges = {"toronto":[0,20000], "miss": [20000,30000], "milton":[30000,35000]}
#     src_counts = {oregs[0]:0, oregs[1]:0} # always only 2 other regs.
#     wkplces = pop_mod.regs[dest].structs.workplace_uid_lists
#     for workplace in wkplces:
#         for uid in workplace:
#             for oreg in oregs:
#                 if uid > ranges[oreg][0] and uid < ranges[oreg][1]:
#                     src_counts[oreg] += 1
                    
#     go_to_come_from[dest] = src_counts

# get total number of workers.
# recreate counts_goto_comefrom.
# some divison.

# %%
src_dest
# Out:
# {'toronto': {'miss': 250, 'milton': 175},
#  'miss': {'toronto': 1640, 'milton': 181},
#  'milton': {'toronto': 591, 'miss': 63}}

# %%
# Normalize the count matrix and calculate the number of people that left. 
# Results: Ratios are perfect. n_left has <20% error. Probably some details behind how they allocate workers.
n_left = {}
import sciris as sc

src_dest_normalized = sc.dcp(src_dest)
for src in src_dest:
    oregs = list(reg_list)
    oregs.remove(src)
    
    total_left = 0
    for dest in oregs:
        total_left += src_dest[src][dest]
    
    # Update entries with normalized values. 
    for dest in oregs:
        src_dest_normalized[src][dest] = src_dest[src][dest]/total_left
    
    n_left[src] = total_left/pop_mod.total_valid_workers[src]
    
print(src_dest_normalized)
print(n_left)
# Out:
# {'toronto': {'miss': 0.5882352941176471, 'milton': 0.4117647058823529}, 'miss': {'toronto': 0.900604063701263, 'milton': 0.09939593629873696}, 'milton': {'toronto': 0.9036697247706422, 'miss': 0.0963302752293578}}
# {'toronto': 0.039213877099095774, 'miss': 0.33678564823377105, 'milton': 0.24707215715904798}

# %%
pop_mod.total_valid_workers["miss"]
# Out:
# 5407

# %%
pop_mod.regs['toronto'].structs.keys()
# Out:
# ['age_by_uid',
#  'fam_income_by_uid',
#  'homes_by_uids',
#  'homes_by_ages',
#  'student_uid_lists',
#  'student_age_lists',
#  'facilities',
#  'facilities_uid_lists',
#  'school_type_by_age',
#  'school_mixing_types',
#  'school_types',
#  'workplaces_by_industry_codes',
#  'teacher_uid_lists',
#  'non_teaching_staff_uid_lists',
#  'workplace_uid_lists',
#  'facilities_staff_uid_lists']

# %% [markdown]
# #### Structures Test ####

# %%
import synthpops as sp
import numpy as np

# %%
pop = sp.Pop.load('population1.pop')
pop_mod = sp.Pop.load('population2.pop')

# %%
# Schools.
# Check if number of schools is equal.
assert len(pop.schools) == len(pop_mod.schools)

# Check if students, teachers, other staff are all equal. 
for i_school in range(len(pop.schools)):
    t_school = pop.schools[i_school] # t for truth
    m_school = pop_mod.schools[i_school] # m for modified
    assert np.array_equal(t_school['student_uids'], m_school['student_uids'])
    assert np.array_equal(t_school['teacher_uids'], m_school['teacher_uids'])
    assert np.array_equal(t_school['non_teaching_staff_uids'], m_school['non_teaching_staff_uids'])
    
# Workplaces
assert len(pop.workplaces) == len(pop_mod.workplaces)

for i_wp in range(len(pop.workplaces)):
    t_wp = pop.workplaces[i_wp]
    m_wp = pop_mod.workplaces[i_wp]
    assert np.array_equal(t_wp['member_uids'], m_wp['member_uids'])

# Homes
t_into_arr = np.array(pop.homes_by_uids, dtype='object')
m_into_arr = np.array(pop_mod.homes_by_uids, dtype='object')

assert np.array_equal(t_into_arr, m_into_arr)

# %%
pop.workplaces[0]
# Out:
# {'member_uids': array([12127, 16896,   708,  9200, 16419,  2882, 11806,  4973, 15606,
#         14449,  7741,  8039,  2633, 10904, 17898, 14365,  2245,  7053,
#          7914,   456,  2732, 17233,  8945]),
#  'wpid': 0}

# %%
pop.homes_by_uids[0][2] = 0

# %% [markdown]
# #### Connections Test ####

# %%
import synthpops as sp
import numpy as np

# %%
pop_truth = sp.Pop.load('population_truth.pop')
pop_mod = sp.Pop.load('population_truth.pop')

# %%
# Surprisingly fast 
pop_truth = pop_truth.popdict
pop_mod = pop_mod.popdict

assert len(pop_truth) == len(pop_mod)

for uid in range(len(pop_truth)):
    for layer in ['H','S','W','C']:
        assert np.array_equal(pop_mod[uid]['contacts'][layer], pop_truth[uid]['contacts'][layer])

# %%
pop_truth
# Out:
# {0: {'age': 43,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [1, 2, 3, 4],
#    'S': [],
#    'W': [8928, 5546, 6191, 7632, 659, 251, 7070],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 0,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 142,
#   'wpindcode': None,
#   'ltcfid': None},
#  1: {'age': 30,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [0, 2, 3, 4],
#    'S': [],
#    'W': [7045,
#     3462,
#     6792,
#     5901,
#     2575,
#     4885,
#     3736,
#     5415,
#     3246,
#     5940,
#     3636,
#     8390,
#     1479,
#     6471,
#     6854,
#     8775,
#     2907,
#     2796,
#     3951],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 0,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 65,
#   'wpindcode': None,
#   'ltcfid': None},
#  2: {'age': 8,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [0, 1, 3, 4],
#    'S': [1798,
#     399,
#     1554,
#     1308,
#     928,
#     1187,
#     817,
#     954,
#     188,
#     963,
#     69,
#     840,
#     596,
#     9047,
#     1117,
#     1635,
#     741,
#     492,
#     622,
#     1647,
#     762],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 0,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  3: {'age': 3,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [0, 1, 2, 4], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 0,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  4: {'age': 12,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [0, 1, 2, 3],
#    'S': [4224,
#     3722,
#     2699,
#     4378,
#     5663,
#     673,
#     1448,
#     2731,
#     177,
#     3124,
#     5174,
#     4419,
#     1356,
#     3277,
#     727,
#     1124,
#     107,
#     1264,
#     1008,
#     3697,
#     5495,
#     3583],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 0,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  5: {'age': 65,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [6], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 1,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  6: {'age': 70,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [5], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 1,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  7: {'age': 55,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [8, 9, 10],
#    'S': [],
#    'W': [3137,
#     6913,
#     8805,
#     5221,
#     9768,
#     712,
#     9512,
#     5720,
#     3852,
#     4173,
#     5912,
#     8473,
#     700,
#     1085,
#     2398],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 2,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 175,
#   'wpindcode': None,
#   'ltcfid': None},
#  8: {'age': 31,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [9, 10, 7],
#    'S': [],
#    'W': [128,
#     4833,
#     9987,
#     387,
#     1959,
#     3560,
#     7307,
#     5388,
#     3343,
#     591,
#     2327,
#     1432,
#     1119],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 2,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  9: {'age': 49,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [8, 10, 7],
#    'S': [],
#    'W': [8068,
#     396,
#     4364,
#     7443,
#     3093,
#     1183,
#     5025,
#     2886,
#     9670,
#     2119,
#     9803,
#     3023,
#     5201,
#     3153,
#     1492,
#     5982,
#     6498,
#     2787,
#     6887,
#     8552,
#     5225,
#     6268],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 2,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  10: {'age': 31,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [8, 9, 7],
#    'S': [],
#    'W': [3169,
#     7618,
#     2691,
#     8452,
#     6887,
#     8231,
#     6824,
#     5482,
#     3080,
#     1198,
#     7698,
#     1138,
#     216,
#     7897,
#     3548,
#     8254],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 2,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  11: {'age': 66,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [12], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 3,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  12: {'age': 60,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [11],
#    'S': [],
#    'W': [7362,
#     1989,
#     9415,
#     5961,
#     5514,
#     5257,
#     6444,
#     1774,
#     6544,
#     8691,
#     918,
#     4316,
#     5630],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 3,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 186,
#   'wpindcode': None,
#   'ltcfid': None},
#  13: {'age': 51,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [9440,
#     1504,
#     9475,
#     8771,
#     4677,
#     2119,
#     8552,
#     6831,
#     7727,
#     883,
#     4951,
#     2879],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 4,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  14: {'age': 25,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [15],
#    'S': [],
#    'W': [8131,
#     3939,
#     3109,
#     518,
#     6693,
#     5095,
#     2730,
#     7882,
#     5644,
#     7822,
#     9231,
#     9586,
#     4851,
#     948,
#     2163,
#     1910,
#     9499,
#     4892],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 5,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 54,
#   'wpindcode': None,
#   'ltcfid': None},
#  15: {'age': 21,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [14],
#    'S': [5313,
#     7429,
#     7883,
#     6636,
#     7309,
#     1421,
#     6127,
#     7922,
#     6579,
#     9337,
#     6106,
#     6779,
#     7646,
#     5727],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 5,
#   'scid': 1,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  16: {'age': 44,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [17, 18, 19, 20],
#    'S': [],
#    'W': [3868],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 6,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 49,
#   'wpindcode': None,
#   'ltcfid': None},
#  17: {'age': 15,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [16, 18, 19, 20],
#    'S': [65,
#     1218,
#     867,
#     2310,
#     1448,
#     1546,
#     1707,
#     3564,
#     4750,
#     3345,
#     3827,
#     5303,
#     920],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 6,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  18: {'age': 5,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [16, 17, 19, 20],
#    'S': [386,
#     899,
#     9860,
#     22,
#     1308,
#     156,
#     1187,
#     1191,
#     9641,
#     810,
#     817,
#     188,
#     960,
#     66,
#     455,
#     840,
#     585,
#     335,
#     347,
#     733,
#     741,
#     108,
#     1262,
#     1647],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 6,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  19: {'age': 16,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [16, 17, 18, 20],
#    'S': [2369,
#     838,
#     1831,
#     3015,
#     3755,
#     4269,
#     2350,
#     2353,
#     274,
#     4627,
#     4563,
#     853,
#     470,
#     119,
#     920,
#     5174,
#     9234,
#     1919],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 6,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  20: {'age': 44,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [16, 17, 18, 19],
#    'S': [],
#    'W': [6272,
#     9096,
#     7049,
#     7305,
#     4749,
#     9488,
#     7568,
#     9233,
#     152,
#     1954,
#     7465,
#     2095,
#     1200,
#     6593,
#     2371,
#     709,
#     3788,
#     6222,
#     5974,
#     9693,
#     1784,
#     2558,
#     5503],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 6,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 119,
#   'wpindcode': None,
#   'ltcfid': None},
#  21: {'age': 55,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [22, 23],
#    'S': [],
#    'W': [5249,
#     7425,
#     4707,
#     260,
#     7513,
#     4842,
#     4138,
#     7821,
#     9359,
#     6002,
#     2803,
#     7093,
#     4693,
#     1431,
#     3961,
#     8477,
#     8478,
#     4831],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 7,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 178,
#   'wpindcode': None,
#   'ltcfid': None},
#  22: {'age': 8,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [21, 23],
#    'S': [645,
#     521,
#     649,
#     523,
#     399,
#     18,
#     149,
#     1308,
#     156,
#     1187,
#     932,
#     1191,
#     552,
#     9641,
#     298,
#     963,
#     455,
#     335,
#     465,
#     9047,
#     347,
#     1117,
#     741,
#     622,
#     1647],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 7,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  23: {'age': 48,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [21, 22], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 7,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  24: {'age': 26,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [25, 26],
#    'S': [],
#    'W': [6240,
#     3810,
#     8727,
#     1833,
#     5034,
#     1322,
#     1162,
#     6478,
#     4880,
#     2737,
#     8850,
#     6225,
#     9397,
#     7509,
#     6838,
#     5147],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 8,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  25: {'age': 2,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [24, 26], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 8,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  26: {'age': 2,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [24, 25], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 8,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  27: {'age': 62,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [1408,
#     7687,
#     6919,
#     3208,
#     7956,
#     5654,
#     1309,
#     8607,
#     7356,
#     3517,
#     4671,
#     9413,
#     8150,
#     4439,
#     5857,
#     4711,
#     3306,
#     2542,
#     750,
#     6012],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 9,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 199,
#   'wpindcode': None,
#   'ltcfid': None},
#  28: {'age': 66,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [29], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 10,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  29: {'age': 70,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [28], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 10,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  30: {'age': 55,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [5214,
#     581,
#     3622,
#     7591,
#     6213,
#     841,
#     5061,
#     9771,
#     495,
#     5104,
#     3283,
#     5845,
#     2422,
#     6839,
#     1497,
#     2011,
#     5054,
#     671],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 11,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  31: {'age': 64,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [32],
#    'S': [],
#    'W': [2060,
#     5132,
#     7058,
#     6678,
#     7193,
#     5529,
#     4509,
#     1578,
#     8240,
#     2354,
#     1334,
#     6842,
#     1604,
#     5852,
#     1121,
#     7423,
#     5478,
#     6124,
#     9198,
#     8566,
#     6519,
#     3450,
#     2175],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 12,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 204,
#   'wpindcode': None,
#   'ltcfid': None},
#  32: {'age': 5,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [31],
#    'S': [1798,
#     149,
#     1308,
#     1316,
#     552,
#     1076,
#     954,
#     319,
#     66,
#     840,
#     585,
#     74,
#     9047,
#     1117,
#     4577,
#     741,
#     1640,
#     492,
#     499],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 12,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  33: {'age': 59,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [34, 35], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 13,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  34: {'age': 1,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [33, 35], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 13,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  35: {'age': 31,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [33, 34],
#    'S': [4481,
#     4896,
#     2338,
#     676,
#     5284,
#     2854,
#     3754,
#     555,
#     432,
#     8784,
#     469,
#     90,
#     992,
#     3583,
#     2676,
#     4471,
#     253,
#     4605,
#     3839],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 13,
#   'scid': 0,
#   'sc_student': None,
#   'sc_teacher': 1,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  36: {'age': 68,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [37], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 14,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  37: {'age': 38,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [36],
#    'S': [],
#    'W': [1504,
#     4839,
#     9480,
#     6888,
#     4556,
#     8624,
#     7344,
#     3089,
#     3313,
#     885,
#     3287,
#     955,
#     3198,
#     7871],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 14,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  38: {'age': 65,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [40, 39], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 15,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  39: {'age': 63,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [40, 38], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 15,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  40: {'age': 16,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [38, 39],
#    'S': [992,
#     2944,
#     738,
#     4290,
#     4038,
#     4135,
#     136,
#     1929,
#     3048,
#     43,
#     811,
#     2129,
#     4241,
#     4245,
#     5495,
#     1628,
#     3583],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 15,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  41: {'age': 63,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [42, 43],
#    'S': [],
#    'W': [1923,
#     3716,
#     2693,
#     8967,
#     5386,
#     6028,
#     3855,
#     7697,
#     5405,
#     1315,
#     1319,
#     8238,
#     181,
#     3388,
#     3774,
#     1744,
#     4702,
#     4062,
#     6243,
#     4580,
#     4204,
#     7413],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 16,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  42: {'age': 2,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [41, 43], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 16,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  43: {'age': 13,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [41, 42],
#    'S': [8704,
#     3722,
#     526,
#     3860,
#     2977,
#     40,
#     1839,
#     1072,
#     2482,
#     966,
#     4041,
#     5842,
#     3563,
#     5743,
#     1264,
#     4594,
#     1140,
#     4215,
#     3070],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 16,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  44: {'age': 48,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [45, 46, 47],
#    'S': [],
#    'W': [8835,
#     516,
#     5388,
#     4492,
#     8207,
#     281,
#     4387,
#     7081,
#     178,
#     5829,
#     8645,
#     3146,
#     5834,
#     2005,
#     342,
#     7518,
#     7775,
#     7907,
#     5606,
#     3440,
#     8052,
#     7289,
#     6908],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 17,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  45: {'age': 3,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [44, 46, 47],
#    'S': [645,
#     649,
#     1164,
#     1687,
#     1177,
#     1050,
#     1308,
#     1316,
#     552,
#     9641,
#     298,
#     817,
#     954,
#     66,
#     455,
#     74,
#     205,
#     338,
#     347,
#     4577,
#     1635,
#     108,
#     622,
#     762],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 17,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  46: {'age': 34,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [44, 45, 47],
#    'S': [],
#    'W': [833,
#     7969,
#     232,
#     4776,
#     522,
#     5675,
#     8429,
#     1678,
#     4783,
#     2768,
#     7634,
#     5458,
#     6836,
#     8251,
#     2205,
#     8895],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 17,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 116,
#   'wpindcode': None,
#   'ltcfid': None},
#  47: {'age': 21,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [44, 45, 46], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 17,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  48: {'age': 24,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 18,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  49: {'age': 42,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [8715,
#     4748,
#     8982,
#     9882,
#     9888,
#     3238,
#     9895,
#     6443,
#     7471,
#     6194,
#     436,
#     6269,
#     9914,
#     5821,
#     1086,
#     7246,
#     6096,
#     3059,
#     4086,
#     120,
#     8573],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 19,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 161,
#   'wpindcode': None,
#   'ltcfid': None},
#  50: {'age': 48,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [51, 52, 53],
#    'S': [],
#    'W': [6080,
#     6946,
#     9895,
#     1834,
#     6443,
#     2639,
#     1904,
#     3471,
#     5971,
#     6933,
#     9557,
#     2138,
#     7839],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 20,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 161,
#   'wpindcode': None,
#   'ltcfid': None},
#  51: {'age': 16,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [50, 52, 53],
#    'S': [1218,
#     771,
#     4230,
#     4136,
#     1385,
#     4394,
#     1068,
#     5663,
#     1042,
#     243,
#     1140,
#     412,
#     572,
#     3263],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 20,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  52: {'age': 26,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [50, 51, 53],
#    'S': [],
#    'W': [1024,
#     7174,
#     787,
#     7316,
#     9760,
#     8609,
#     1698,
#     8736,
#     807,
#     7859,
#     9912,
#     9918,
#     1090,
#     3527,
#     4939,
#     8013,
#     7252,
#     8404,
#     2135,
#     488,
#     623],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 20,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 67,
#   'wpindcode': None,
#   'ltcfid': None},
#  53: {'age': 47,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [50, 51, 52],
#    'S': [],
#    'W': [5858,
#     5218,
#     2754,
#     4710,
#     8807,
#     5195,
#     941,
#     8846,
#     4335,
#     8274,
#     7827,
#     1721,
#     8983,
#     8121,
#     6044,
#     190,
#     3135],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 20,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 93,
#   'wpindcode': None,
#   'ltcfid': None},
#  54: {'age': 66,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [55], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 21,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  55: {'age': 38,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [54], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 21,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  56: {'age': 36,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [], 'S': [], 'W': [1756, 9869, 3694], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 22,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 26,
#   'wpindcode': None,
#   'ltcfid': None},
#  57: {'age': 43,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [58], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 23,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  58: {'age': 4,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [57], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 23,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  59: {'age': 42,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [60, 61, 62, 63],
#    'S': [],
#    'W': [8992,
#     6849,
#     612,
#     7461,
#     3941,
#     6790,
#     3911,
#     5243,
#     719,
#     3824,
#     2815,
#     5172,
#     468,
#     6518,
#     6679,
#     8475,
#     1630,
#     6911],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 24,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 79,
#   'wpindcode': None,
#   'ltcfid': None},
#  60: {'age': 3,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [59, 61, 62, 63], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 24,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  61: {'age': 1,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [59, 60, 62, 63], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 24,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  62: {'age': 35,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [59, 60, 61, 63],
#    'S': [],
#    'W': [7233, 3718, 1862, 2955, 1003, 8593, 1594, 3164, 9374],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 24,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 61,
#   'wpindcode': None,
#   'ltcfid': None},
#  63: {'age': 43,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [59, 60, 61, 62],
#    'S': [],
#    'W': [4353,
#     2177,
#     9090,
#     1028,
#     772,
#     3732,
#     151,
#     7328,
#     4390,
#     7474,
#     4917,
#     5047,
#     8251,
#     444,
#     833,
#     835,
#     2509,
#     3411,
#     6623,
#     2403,
#     9449,
#     6125,
#     887,
#     8952],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 24,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 116,
#   'wpindcode': None,
#   'ltcfid': None},
#  64: {'age': 18,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [258,
#     838,
#     1385,
#     3564,
#     3756,
#     1356,
#     2352,
#     2129,
#     1053,
#     1072,
#     3697,
#     2133,
#     1654,
#     4563,
#     797],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 25,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  65: {'age': 64,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [66, 67],
#    'S': [647,
#     17,
#     3860,
#     4374,
#     2336,
#     1825,
#     4515,
#     4903,
#     3755,
#     1068,
#     429,
#     1581,
#     5038,
#     561,
#     1079,
#     2114,
#     2121,
#     208,
#     853,
#     86,
#     854,
#     1386,
#     5746,
#     3839,
#     3583],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 26,
#   'scid': 0,
#   'sc_student': None,
#   'sc_teacher': 1,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  66: {'age': 5,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [65, 67],
#    'S': [645,
#     521,
#     18,
#     149,
#     32,
#     932,
#     1316,
#     678,
#     810,
#     45,
#     573,
#     69,
#     840,
#     465,
#     338,
#     596,
#     9047,
#     472,
#     347,
#     733,
#     4577,
#     499],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 26,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  67: {'age': 46,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [65, 66], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 26,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  68: {'age': 39,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [69, 70, 71, 72],
#    'S': [],
#    'W': [2438,
#     6282,
#     5004,
#     7187,
#     5528,
#     8728,
#     4122,
#     1178,
#     679,
#     686,
#     1710,
#     9397,
#     6968,
#     5818,
#     7617,
#     4680,
#     3018,
#     715,
#     9428,
#     7895,
#     5593,
#     3812,
#     9199,
#     4463,
#     9327,
#     8308],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 27,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  69: {'age': 5,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [68, 70, 71, 72],
#    'S': [2,
#     649,
#     1417,
#     1164,
#     1554,
#     149,
#     1177,
#     156,
#     552,
#     813,
#     188,
#     573,
#     9921,
#     66,
#     71,
#     74,
#     472,
#     1117,
#     1640,
#     622],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 27,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  70: {'age': 10,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [68, 69, 71, 72],
#    'S': [681, 3051, 588, 429, 3883, 1168, 8784, 5174, 183, 88, 412, 5495],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 27,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  71: {'age': 5,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [68, 69, 70, 72],
#    'S': [4577,
#     1187,
#     69,
#     741,
#     1798,
#     649,
#     810,
#     1164,
#     813,
#     9047,
#     211,
#     1687,
#     954,
#     156],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 27,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  72: {'age': 29,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [68, 69, 70, 71],
#    'S': [],
#    'W': [9346,
#     3595,
#     8076,
#     6936,
#     9883,
#     3228,
#     6303,
#     8736,
#     4279,
#     9912,
#     5433,
#     7498,
#     4939,
#     7894,
#     2135,
#     5223,
#     3819,
#     623,
#     7035],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 27,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 67,
#   'wpindcode': None,
#   'ltcfid': None},
#  73: {'age': 33,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [74],
#    'S': [],
#    'W': [4161,
#     2594,
#     3299,
#     5703,
#     459,
#     2636,
#     1579,
#     4846,
#     5870,
#     4592,
#     5392,
#     6738,
#     9902,
#     3032,
#     3897,
#     3800,
#     1369],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 28,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  74: {'age': 8,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [73],
#    'S': [9860,
#     1798,
#     521,
#     1177,
#     1050,
#     156,
#     32,
#     45,
#     442,
#     954,
#     188,
#     9921,
#     69,
#     585,
#     465,
#     338,
#     9047,
#     741,
#     1134,
#     1647],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 28,
#   'scid': 2,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  75: {'age': 85,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [76], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 29,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  76: {'age': 48,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [75],
#    'S': [],
#    'W': [4576,
#     1216,
#     9314,
#     2470,
#     1895,
#     4680,
#     1545,
#     6184,
#     2636,
#     6927,
#     5424,
#     9298,
#     6739,
#     2004,
#     2422,
#     3959,
#     8863],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 29,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  77: {'age': 66,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [78, 79], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 30,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  78: {'age': 26,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [77, 79],
#    'S': [],
#    'W': [6114,
#     5765,
#     4293,
#     133,
#     4968,
#     1838,
#     2222,
#     9327,
#     8083,
#     5045,
#     1655,
#     6202],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 30,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  79: {'age': 62,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [77, 78],
#    'S': [],
#    'W': [229, 6278, 8485, 5290, 1483, 9141, 1656, 2047],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 30,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 156,
#   'wpindcode': None,
#   'ltcfid': None},
#  80: {'age': 55,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [81, 82],
#    'S': [],
#    'W': [6408,
#     3083,
#     9867,
#     8592,
#     287,
#     7584,
#     1450,
#     4139,
#     4292,
#     1353,
#     8010,
#     6865,
#     5463,
#     8921,
#     3932,
#     354,
#     7523,
#     2277,
#     3687,
#     8169,
#     7919,
#     6900],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 31,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 198,
#   'wpindcode': None,
#   'ltcfid': None},
#  81: {'age': 16,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [80, 82],
#    'S': [1570,
#     676,
#     997,
#     4869,
#     5284,
#     4106,
#     3435,
#     2701,
#     174,
#     783,
#     1712,
#     4830,
#     5649,
#     3827,
#     4533,
#     5525,
#     798],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 31,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  82: {'age': 28,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [80, 81],
#    'S': [],
#    'W': [4872,
#     3594,
#     3731,
#     9753,
#     8995,
#     3619,
#     166,
#     9386,
#     5051,
#     6077,
#     3005,
#     4674,
#     8901,
#     4948,
#     5338,
#     1506,
#     8295,
#     2535,
#     8692,
#     8565],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 31,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 167,
#   'wpindcode': None,
#   'ltcfid': None},
#  83: {'age': 54,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [84, 85, 86], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 32,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  84: {'age': 49,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [83, 85, 86],
#    'S': [],
#    'W': [4992,
#     896,
#     2050,
#     2707,
#     9876,
#     2453,
#     9239,
#     4123,
#     9385,
#     2094,
#     4784,
#     2366,
#     6271,
#     219,
#     223,
#     6240,
#     7007,
#     5859,
#     5870,
#     3711],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 32,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  85: {'age': 17,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [83, 84, 86],
#    'S': [5262,
#     2325,
#     4378,
#     2597,
#     4136,
#     1072,
#     2482,
#     4275,
#     966,
#     326,
#     3922,
#     979,
#     2393,
#     2778,
#     90,
#     1762,
#     867,
#     1512,
#     3564],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 32,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  86: {'age': 15,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [83, 84, 85],
#    'S': [3992,
#     288,
#     1448,
#     170,
#     65,
#     4546,
#     4547,
#     3140,
#     4041,
#     5066,
#     4043,
#     3922,
#     992,
#     1249,
#     1765,
#     743,
#     1386,
#     243,
#     5621,
#     4215,
#     895],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 32,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  87: {'age': 41,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [88, 89, 90],
#    'S': [],
#    'W': [4324, 7210, 8715, 4045, 594, 3059, 8244, 6933, 9557, 445, 8767],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 33,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 161,
#   'wpindcode': None,
#   'ltcfid': None},
#  88: {'age': 16,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [89, 90, 87],
#    'S': [9607,
#     1929,
#     5262,
#     2583,
#     5663,
#     2731,
#     556,
#     5038,
#     1839,
#     2352,
#     3508,
#     1980,
#     4547,
#     3140,
#     70,
#     3015,
#     738,
#     5743,
#     1264,
#     2676,
#     504,
#     4221],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 33,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  89: {'age': 24,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [88, 90, 87], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 33,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  90: {'age': 13,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [88, 89, 87],
#    'S': [2699,
#     907,
#     35,
#     4136,
#     555,
#     174,
#     5303,
#     3261,
#     189,
#     2365,
#     3263,
#     4676,
#     326,
#     85,
#     3547,
#     2274,
#     100,
#     235,
#     3564,
#     238,
#     5746,
#     253,
#     3839],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 33,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  91: {'age': 30,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [6851,
#     3677,
#     4005,
#     7015,
#     6281,
#     8399,
#     6351,
#     1585,
#     8848,
#     4822,
#     7323,
#     5917,
#     3678,
#     5823],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 34,
#   'scid': 3,
#   'sc_student': None,
#   'sc_teacher': 1,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  92: {'age': 61,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [93],
#    'S': [],
#    'W': [7687,
#     5640,
#     3208,
#     6186,
#     3306,
#     138,
#     5837,
#     6094,
#     4910,
#     1104,
#     7658,
#     275,
#     1748,
#     9364,
#     8150,
#     7606,
#     574],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 35,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 199,
#   'wpindcode': None,
#   'ltcfid': None},
#  93: {'age': 33,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [92], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 35,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  94: {'age': 33,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [6791,
#     1676,
#     8847,
#     408,
#     3742,
#     8740,
#     2600,
#     6952,
#     1832,
#     2221,
#     4782,
#     2864,
#     5425,
#     9649,
#     1593,
#     1337,
#     2875,
#     6598,
#     7884,
#     3662,
#     5456,
#     6482,
#     4307,
#     1107,
#     6487,
#     3549,
#     9694,
#     8031,
#     4835,
#     2408,
#     2286,
#     7289,
#     9981],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 36,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  95: {'age': 31,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [96, 97, 98], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 37,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  96: {'age': 10,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [97, 98, 95],
#    'S': [2944,
#     2583,
#     920,
#     664,
#     5021,
#     414,
#     2468,
#     1448,
#     3124,
#     2111,
#     1731,
#     582,
#     3410,
#     5716,
#     2392,
#     738,
#     235,
#     3051,
#     1006,
#     5495,
#     504,
#     1275],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 37,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  97: {'age': 33,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [96, 98, 95],
#    'S': [],
#    'W': [2305,
#     8324,
#     516,
#     5636,
#     8069,
#     6283,
#     4387,
#     3370,
#     5037,
#     3887,
#     7096,
#     8123,
#     3392,
#     2880,
#     3143,
#     8910,
#     5847,
#     9692,
#     6501,
#     6387,
#     6392],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 37,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  98: {'age': 36,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [96, 97, 95],
#    'S': [],
#    'W': [8463,
#     9752,
#     3239,
#     937,
#     1962,
#     8773,
#     2122,
#     5962,
#     2893,
#     7758,
#     3295,
#     8161,
#     870,
#     9454,
#     2670,
#     4980,
#     3318,
#     7163,
#     1535],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 37,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 44,
#   'wpindcode': None,
#   'ltcfid': None},
#  99: {'age': 62,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 38,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  100: {'age': 18,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [4750,
#     4756,
#     4245,
#     2977,
#     3236,
#     5284,
#     2854,
#     4136,
#     1839,
#     4402,
#     572,
#     1342,
#     966,
#     4297,
#     90,
#     4830,
#     2655,
#     738,
#     5094,
#     107,
#     2668,
#     2928,
#     888],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 39,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  101: {'age': 46,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [104, 102, 103], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 40,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
# ...
#   'hhid': 404,
#   'scid': 1,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  968: {'age': 46,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [964, 965, 966, 967],
#    'S': [],
#    'W': [2874, 915],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 404,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 36,
#   'wpindcode': None,
#   'ltcfid': None},
#  969: {'age': 73,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [970], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 405,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  970: {'age': 87,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [969], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 405,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  971: {'age': 41,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [972, 973, 974],
#    'S': [],
#    'W': [3479,
#     4867,
#     4618,
#     6076,
#     8951,
#     1837,
#     8522,
#     1130,
#     8171,
#     7318,
#     2364,
#     7415,
#     8572,
#     8637,
#     3646],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 406,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 21,
#   'wpindcode': None,
#   'ltcfid': None},
#  972: {'age': 3,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [971, 973, 974], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 406,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  973: {'age': 2,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [971, 972, 974], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 406,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  974: {'age': 42,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [971, 972, 973],
#    'S': [],
#    'W': [1422,
#     5531,
#     6049,
#     7332,
#     6568,
#     5811,
#     3003,
#     9150,
#     9279,
#     4544,
#     2766,
#     1232,
#     5469,
#     225,
#     9186,
#     9317,
#     2792,
#     8050,
#     8186],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 406,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 131,
#   'wpindcode': None,
#   'ltcfid': None},
#  975: {'age': 26,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [],
#    'W': [7171,
#     6283,
#     8716,
#     8849,
#     8093,
#     3748,
#     2221,
#     3511,
#     8123,
#     9915,
#     3392,
#     2246,
#     4423,
#     710,
#     4553,
#     4687,
#     3666,
#     7507,
#     6105,
#     222,
#     1769],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 407,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  976: {'age': 49,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [977, 978, 979, 980],
#    'S': [],
#    'W': [1155,
#     8203,
#     9212,
#     7834,
#     8347,
#     5661,
#     4639,
#     8738,
#     1208,
#     5691,
#     7487,
#     9537,
#     9026,
#     6856,
#     5320,
#     3915,
#     5593,
#     1248,
#     4969,
#     7033,
#     4988],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 408,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  977: {'age': 16,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [976, 978, 979, 980],
#    'S': [9607,
#     136,
#     1160,
#     1929,
#     654,
#     274,
#     3348,
#     3860,
#     661,
#     4378,
#     4252,
#     3104,
#     1570,
#     680,
#     555,
#     432,
#     4272,
#     4275,
#     4929,
#     1092,
#     4038,
#     199,
#     2121,
#     4041,
#     1356,
#     4431,
#     3410,
#     5716,
#     1124,
#     235,
#     1519,
#     757,
#     895],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 408,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  978: {'age': 43,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [976, 977, 979, 980],
#    'S': [],
#    'W': [3458,
#     6915,
#     4617,
#     4366,
#     7572,
#     5276,
#     3231,
#     5153,
#     3249,
#     7866,
#     3771,
#     7359,
#     6977,
#     2242,
#     3159,
#     9055,
#     8038,
#     3049,
#     3441,
#     2545,
#     2685],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 408,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 2,
#   'wpindcode': None,
#   'ltcfid': None},
#  979: {'age': 17,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [976, 977, 978, 980],
#    'S': [771,
#     4230,
#     9607,
#     5649,
#     2583,
#     4896,
#     673,
#     2209,
#     1448,
#     428,
#     561,
#     2353,
#     2226,
#     1218,
#     85,
#     859,
#     2537,
#     2934,
#     631,
#     1275,
#     4605],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 408,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  980: {'age': 8,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [976, 977, 978, 979],
#    'S': [4098,
#     2442,
#     2570,
#     2067,
#     7315,
#     9107,
#     6433,
#     2723,
#     4003,
#     1575,
#     6316,
#     1585,
#     8625,
#     8755,
#     6962,
#     7351,
#     5186,
#     5188,
#     6860,
#     6230,
#     2650,
#     8923,
#     6366,
#     2014,
#     4205,
#     8824],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 408,
#   'scid': 3,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  981: {'age': 30,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [982, 983, 984, 985, 986, 987],
#    'S': [],
#    'W': [4884,
#     3733,
#     5015,
#     4773,
#     3628,
#     3507,
#     1845,
#     1208,
#     3897,
#     7105,
#     3794,
#     2515,
#     4051,
#     1623,
#     5475,
#     5733,
#     1643,
#     4848,
#     9970,
#     4091,
#     5247],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  982: {'age': 62,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [981, 983, 984, 985, 986, 987],
#    'S': [],
#    'W': [3393,
#     4675,
#     3652,
#     260,
#     4138,
#     7821,
#     9359,
#     4559,
#     7801,
#     2803,
#     1403,
#     7093,
#     1431,
#     4664,
#     3961,
#     7483,
#     3998],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 178,
#   'wpindcode': None,
#   'ltcfid': None},
#  983: {'age': 32,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [981, 982, 984, 985, 986, 987],
#    'S': [],
#    'W': [9736,
#     2826,
#     9488,
#     410,
#     2844,
#     1954,
#     1328,
#     2491,
#     956,
#     1853,
#     9788,
#     5824,
#     2371,
#     8006,
#     6601,
#     3788,
#     6222,
#     1618,
#     8531,
#     5974,
#     7768,
#     9178,
#     5467,
#     9307,
#     4322,
#     5092,
#     4200,
#     8554,
#     2158,
#     2802,
#     6004,
#     5752,
#     6015],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 119,
#   'wpindcode': None,
#   'ltcfid': None},
#  984: {'age': 30,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [981, 982, 983, 985, 986, 987],
#    'S': [],
#    'W': [4129, 8421, 5477, 6861, 1107, 3126, 6391, 3030, 6105, 8826, 4925],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 59,
#   'wpindcode': None,
#   'ltcfid': None},
#  985: {'age': 33,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [981, 982, 983, 984, 986, 987],
#    'S': [],
#    'W': [8259, 135, 4363, 1325, 2902, 2230, 6614, 3807],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 134,
#   'wpindcode': None,
#   'ltcfid': None},
#  986: {'age': 59,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [981, 982, 983, 984, 985, 987],
#    'S': [],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  987: {'age': 32,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [981, 982, 983, 984, 985, 986],
#    'S': [],
#    'W': [1534, 1639],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 409,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 33,
#   'wpindcode': None,
#   'ltcfid': None},
#  988: {'age': 59,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [989, 990, 991], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 410,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  989: {'age': 22,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [988, 990, 991],
#    'S': [],
#    'W': [778,
#     4746,
#     8460,
#     2700,
#     790,
#     2853,
#     296,
#     6185,
#     6824,
#     4662,
#     8506,
#     9149,
#     5461,
#     9439,
#     8671,
#     1125,
#     8170,
#     9075,
#     8568,
#     8058],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 410,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 115,
#   'wpindcode': None,
#   'ltcfid': None},
#  990: {'age': 17,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [988, 989, 991],
#    'S': [4481,
#     771,
#     3876,
#     3140,
#     326,
#     743,
#     1831,
#     1929,
#     2845,
#     4291,
#     2350,
#     3151,
#     4272,
#     4563,
#     3508,
#     4378,
#     189],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 410,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  991: {'age': 27,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [988, 989, 990],
#    'S': [],
#    'W': [8440,
#     1924,
#     3463,
#     3401,
#     1641,
#     5994,
#     4941,
#     9774,
#     4079,
#     9840,
#     1489,
#     3349,
#     9782,
#     4120,
#     1595,
#     9211],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 410,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 135,
#   'wpindcode': None,
#   'ltcfid': None},
#  992: {'age': 18,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [],
#    'S': [3591,
#     526,
#     3345,
#     2709,
#     1557,
#     4374,
#     2073,
#     414,
#     1184,
#     35,
#     3876,
#     2597,
#     806,
#     40,
#     1448,
#     555,
#     1712,
#     4402,
#     3508,
#     4533,
#     6199,
#     447,
#     4290,
#     966,
#     4043,
#     208,
#     469,
#     86,
#     218,
#     867,
#     2537,
#     107,
#     363,
#     4093,
#     1652,
#     253],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 411,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  993: {'age': 83,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [994], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 412,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  994: {'age': 54,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [993], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 412,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  995: {'age': 52,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [996, 997], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 413,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  996: {'age': 49,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [995, 997],
#    'S': [],
#    'W': [6018,
#     5765,
#     7569,
#     6931,
#     7701,
#     1433,
#     1948,
#     2470,
#     1833,
#     9385,
#     4015,
#     4658,
#     4788,
#     6458,
#     1216,
#     5320,
#     2252,
#     2515,
#     6232,
#     5215,
#     4195,
#     2285,
#     505,
#     637],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 413,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  997: {'age': 18,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [995, 996],
#    'S': [261,
#     4232,
#     3722,
#     4750,
#     3345,
#     274,
#     9234,
#     2325,
#     1570,
#     1061,
#     4135,
#     5038,
#     179,
#     824,
#     5690,
#     4929,
#     1609,
#     81,
#     2663,
#     5621,
#     119],
#    'W': [],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 413,
#   'scid': 0,
#   'sc_student': 1,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  998: {'age': 61,
#   'sex': 1,
#   'loc': None,
#   'contacts': {'H': [1000, 999], 'S': [], 'W': [], 'C': [], 'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 414,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': None,
#   'wpindcode': None,
#   'ltcfid': None},
#  999: {'age': 59,
#   'sex': 0,
#   'loc': None,
#   'contacts': {'H': [1000, 998],
#    'S': [],
#    'W': [6018,
#     5392,
#     8728,
#     2466,
#     8871,
#     4276,
#     8894,
#     5063,
#     6219,
#     6225,
#     9938,
#     6617,
#     3166,
#     864,
#     6114,
#     4198,
#     4969,
#     1133,
#     1267,
#     4339,
#     6260,
#     9982,
#     6271],
#    'C': [],
#    'LTCF': []},
#   'ltcf_res': None,
#   'ltcf_staff': None,
#   'hhid': 414,
#   'scid': None,
#   'sc_student': None,
#   'sc_teacher': None,
#   'sc_staff': None,
#   'sc_type': None,
#   'sc_mixing_type': None,
#   'wpid': 163,
#   'wpindcode': None,
#   'ltcfid': None},
#  ...}

# %% [markdown]
# #### Playing with kwargs ####

# %%
params_ca = dict(name = 'toronto', n=20000, com_contacts=20) # large city
params_cb = dict(name = 'miss', n=10000, com_contacts=10) # medium city
params_cc = dict(name = 'milton', n=5000,  com_contacts=10) # small city
all_params = dict(one = params_ca, two = params_cb, three = params_cc)


def multi_sim(mixing_pars, *foo):
    for item in foo:
        behaviour_model(**item)
    print(len(foo))
#     print(kwargs)
def behaviour_model(**foo):
    for key, item in foo.items():
        print("{}: {}".format(key, item))

# Interface: just pass as **kwargs rather than a whole dict, for more options.
multi_sim('foo', *(params_ca, params_cb, params_cc))
# Out:
# name: toronto
# n: 20000
# com_contacts: 20
# name: miss
# n: 10000
# com_contacts: 10
# name: milton
# n: 5000
# com_contacts: 10
# 3

# %%
params_ca = dict(name = 'toronto', n=20000, com_contacts=20) # large city
params_cb = dict(name = 'miss', n=10000, com_contacts=10) # medium city
params_cc = dict(name = 'milton', n=5000,  com_contacts=10) # small city
all_params = dict(one = params_ca, two = params_cb, three = params_cc)

**all_params
# Out:
#   File "/tmp/ipykernel_15757/2070570882.py", line 6
#     **all_params
#     ^
# SyntaxError: invalid syntax

# %%
num_cities = 3
come_from_cur = 0.8
come_from_others = 0.2


ret = (come_from_others/(num_cities-1))* \
    np.ones((num_cities, num_cities))
for i in range(ret.shape[0]):
    ret[i][i] = come_from_cur

# %%
ret
# Out:
# array([[0.8, 0.1, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.1, 0.8]])

# %%
import sciris as sc

# %%
a = dict(name = 'toronto', n=20000, com_contacts=20)
b = sc.objdict(a)

# %%
b.pop('name')
# Out:
# 'toronto'

# %%
b
# Out:
# #0. 'n':            20000
# #1. 'com_contacts': 20

# %%
a.pop('name')
# Out:
# 'toronto'

# %%
a
# Out:
# {'n': 20000, 'com_contacts': 20}
