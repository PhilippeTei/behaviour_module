# %%
import behaviour as bh
import pathosim as inf 
import numpy as np
import synthpops as sp
import sciris as sc
# Out:
# PathoSim 3.1.2 (2022-01-16) — © 2023 by McGill University

# %%
pars = {'n': 10e3, 'sheet_name': 'Canada','country_location': 'canada','use_default': True}

# %%
canada_pop = bh.BehaviourModel(pars)
# Out:
# Initializing Behaviour Module...
# ========== setting country location = canada

# %%
BC_pop = bh.BehaviourModel({'n': 10e3, 'sheet_name': 'Canada','country_location': 'canada', 'state_location': 'BC', 'use_default': True})
# Out:
# Initializing Behaviour Module...
# ========== setting country location = canada

# %%
import behaviour as bh
import pathosim as inf 
import numpy as np
import sciris as sc

# ---- DEMO SHOWCASING TESTING AND CONTACT TRACING INTERVENTIONS ---- #

#Define basic simulation parameters
n_days = 365
pop_size = 10000
   
#Create synthetic population using the BehaviourModel module
pop = BC_pop


#Create pathogens (2 pathogens which in this case are 2 pathogen with SARS-CoV-2 parameters)
covid = inf.SARS_COV_2(100)  
second_path = inf.SARS_COV_2(100)
second_path.label = 'Covid 2' 

#Create testing interventions and specify as an argument the pathogen it is for
tn = inf.test_num(daily_tests=500, pathogen = 0)
tn1 = inf.test_num(daily_tests=500, pathogen = 1) 

#Alternative testing intervention, based on probabilities:
#tp = inf.test_prob(symp_prob=0.2, asymp_prob=0.001, symp_quar_prob=1.0, asymp_quar_prob=1.0, do_plot=False, pathogen = 0)
#tp2 = inf.test_prob(symp_prob=0.2, asymp_prob=0.001, symp_quar_prob=1.0, asymp_quar_prob=1.0, do_plot=False, pathogen = 1) 


#create the contact tracing intervention and specify which pathogens are affected as an array of pathogens
#ct = inf.contact_tracing(trace_probs=dict(h=1.0, s=0.5, w=0.5, c=0.3), do_plot=False, pathogens = [0,1])   #Quarantining after notified
nc = inf.notify_contacts(trace_probs={'h': 1, 's': 0.2, 'w': 0.2, 'c': 0.03},                               #Just notification
                                  trace_time={'h': 0, 's': 1, 'w': 1, 'c': 2}, pathogens = [0])

#Run the simulation
sim = inf.Sim(pop_size=pop_size, people = pop, n_days=n_days, interventions = [tn1, tn], pathogens = [covid, second_path])  
sim.run()     
 
sim.plot('multi-pathogen') #Plot using specific display settings for multi-pathogen. Shows co-infections.
# Out:
# Initializing sim with 10000 people for 365 days
#   Running 2020-03-01 ( 0/365) (2.83 s)  ———————————————————— 0%
#   Running 2020-03-11 (10/365) (3.12 s)  ———————————————————— 3%
#   Running 2020-03-21 (20/365) (3.49 s)  •——————————————————— 6%
#   Running 2020-03-31 (30/365) (3.85 s)  •——————————————————— 8%
#   Running 2020-04-10 (40/365) (4.19 s)  ••—————————————————— 11%
#   Running 2020-04-20 (50/365) (4.55 s)  ••—————————————————— 14%
#   Running 2020-04-30 (60/365) (4.93 s)  •••————————————————— 17%
#   Running 2020-05-10 (70/365) (5.33 s)  •••————————————————— 19%
#   Running 2020-05-20 (80/365) (5.77 s)  ••••———————————————— 22%
#   Running 2020-05-30 (90/365) (6.19 s)  ••••———————————————— 25%
#   Running 2020-06-09 (100/365) (6.71 s)  •••••——————————————— 28%
#   Running 2020-06-19 (110/365) (7.34 s)  ••••••—————————————— 30%
#   Running 2020-06-29 (120/365) (7.79 s)  ••••••—————————————— 33%
#   Running 2020-07-09 (130/365) (8.23 s)  •••••••————————————— 36%
#   Running 2020-07-19 (140/365) (8.66 s)  •••••••————————————— 39%
#   Running 2020-07-29 (150/365) (9.08 s)  ••••••••———————————— 41%
#   Running 2020-08-08 (160/365) (9.48 s)  ••••••••———————————— 44%
#   Running 2020-08-18 (170/365) (9.86 s)  •••••••••——————————— 47%
#   Running 2020-08-28 (180/365) (10.23 s)  •••••••••——————————— 49%
#   Running 2020-09-07 (190/365) (10.58 s)  ••••••••••—————————— 52%
#   Running 2020-09-17 (200/365) (10.91 s)  ••••••••••—————————— 55%
#   Running 2020-09-27 (210/365) (11.24 s)  •••••••••••————————— 58%
#   Running 2020-10-07 (220/365) (11.54 s)  ••••••••••••———————— 60%
#   Running 2020-10-17 (230/365) (11.83 s)  ••••••••••••———————— 63%
#   Running 2020-10-27 (240/365) (12.12 s)  •••••••••••••——————— 66%
#   Running 2020-11-06 (250/365) (12.40 s)  •••••••••••••——————— 69%
#   Running 2020-11-16 (260/365) (12.66 s)  ••••••••••••••—————— 71%
#   Running 2020-11-26 (270/365) (12.94 s)  ••••••••••••••—————— 74%
#   Running 2020-12-06 (280/365) (13.21 s)  •••••••••••••••————— 77%
#   Running 2020-12-16 (290/365) (13.46 s)  •••••••••••••••————— 80%
#   Running 2020-12-26 (300/365) (13.71 s)  ••••••••••••••••———— 82%
#   Running 2021-01-05 (310/365) (13.97 s)  ••••••••••••••••———— 85%
#   Running 2021-01-15 (320/365) (14.23 s)  •••••••••••••••••——— 88%
#   Running 2021-01-25 (330/365) (14.49 s)  ••••••••••••••••••—— 90%
#   Running 2021-02-04 (340/365) (14.75 s)  ••••••••••••••••••—— 93%
#   Running 2021-02-14 (350/365) (14.99 s)  •••••••••••••••••••— 96%
#   Running 2021-02-24 (360/365) (15.21 s)  •••••••••••••••••••— 99%
#
# Simulation summary:
#         Summary of pathogen SARS-CoV-2:
#              9,766 cumulative infections
#              2,447 cumulative reinfections
#              9,752 cumulative infectious
#              6,271 cumulative symptomatic cases
#                506 cumulative severe cases
#                169 cumulative critical cases
#              9,636 cumulative recoveries
#                 86 cumulative deaths
#            183,000 cumulative tests
#              5,883 cumulative diagnoses
#                 59 cumulative known deaths
#                  0 cumulative vaccine doses
#                  0 cumulative vaccinated people
#                  0 cumulative diagnoses with custom testing module
#
#         Summary of pathogen Covid 2:
#              9,411 cumulative infections
#              1,838 cumulative reinfections
#              9,411 cumulative infectious
#              6,141 cumulative symptomatic cases
#                496 cumulative severe cases
#                155 cumulative critical cases
#              9,341 cumulative recoveries
#                 68 cumulative deaths
#            183,000 cumulative tests
#              5,342 cumulative diagnoses
#                 43 cumulative known deaths
#                  0 cumulative vaccine doses
#                  0 cumulative vaccinated people
#                  0 cumulative diagnoses with custom testing module
#
#                119 cumulative co-infections
#             10,955 cumulative isolations started
#                  0 cumulative quarantines started

# %%
import behaviour as bh
import pathosim as inf 
import numpy as np
import sciris as sc

# ---- DEMO SHOWCASING TESTING AND CONTACT TRACING INTERVENTIONS ---- #

#Define basic simulation parameters
n_days = 365
pop_size = 10000
   
#Create synthetic population using the BehaviourModel module
pop = canada_pop


#Create pathogens (2 pathogens which in this case are 2 pathogen with SARS-CoV-2 parameters)
covid = inf.SARS_COV_2(100)  
second_path = inf.SARS_COV_2(100)
second_path.label = 'Covid 2' 

#Create testing interventions and specify as an argument the pathogen it is for
tn = inf.test_num(daily_tests=500, pathogen = 0)
tn1 = inf.test_num(daily_tests=500, pathogen = 1) 

#Alternative testing intervention, based on probabilities:
#tp = inf.test_prob(symp_prob=0.2, asymp_prob=0.001, symp_quar_prob=1.0, asymp_quar_prob=1.0, do_plot=False, pathogen = 0)
#tp2 = inf.test_prob(symp_prob=0.2, asymp_prob=0.001, symp_quar_prob=1.0, asymp_quar_prob=1.0, do_plot=False, pathogen = 1) 


#create the contact tracing intervention and specify which pathogens are affected as an array of pathogens
#ct = inf.contact_tracing(trace_probs=dict(h=1.0, s=0.5, w=0.5, c=0.3), do_plot=False, pathogens = [0,1])   #Quarantining after notified
nc = inf.notify_contacts(trace_probs={'h': 1, 's': 0.2, 'w': 0.2, 'c': 0.03},                               #Just notification
                                  trace_time={'h': 0, 's': 1, 'w': 1, 'c': 2}, pathogens = [0])

#Run the simulation
sim = inf.Sim(pop_size=pop_size, people = pop, n_days=n_days, interventions = [tn1, tn], pathogens = [covid, second_path])  
sim.run()     
 
sim.plot('multi-pathogen') #Plot using specific display settings for multi-pathogen. Shows co-infections.
# Out:
# Initializing sim with 10000 people for 365 days
#   Running 2020-03-01 ( 0/365) (1.70 s)  ———————————————————— 0%
#   Running 2020-03-11 (10/365) (1.87 s)  ———————————————————— 3%
#   Running 2020-03-21 (20/365) (2.08 s)  •——————————————————— 6%
#   Running 2020-03-31 (30/365) (2.31 s)  •——————————————————— 8%
#   Running 2020-04-10 (40/365) (2.58 s)  ••—————————————————— 11%
#   Running 2020-04-20 (50/365) (2.82 s)  ••—————————————————— 14%
#   Running 2020-04-30 (60/365) (3.09 s)  •••————————————————— 17%
#   Running 2020-05-10 (70/365) (3.35 s)  •••————————————————— 19%
#   Running 2020-05-20 (80/365) (3.64 s)  ••••———————————————— 22%
#   Running 2020-05-30 (90/365) (3.89 s)  ••••———————————————— 25%
#   Running 2020-06-09 (100/365) (4.20 s)  •••••——————————————— 28%
#   Running 2020-06-19 (110/365) (4.51 s)  ••••••—————————————— 30%
#   Running 2020-06-29 (120/365) (4.83 s)  ••••••—————————————— 33%
#   Running 2020-07-09 (130/365) (5.12 s)  •••••••————————————— 36%
#   Running 2020-07-19 (140/365) (5.40 s)  •••••••————————————— 39%
#   Running 2020-07-29 (150/365) (5.71 s)  ••••••••———————————— 41%
#   Running 2020-08-08 (160/365) (6.01 s)  ••••••••———————————— 44%
#   Running 2020-08-18 (170/365) (6.31 s)  •••••••••——————————— 47%
#   Running 2020-08-28 (180/365) (6.59 s)  •••••••••——————————— 49%
#   Running 2020-09-07 (190/365) (6.85 s)  ••••••••••—————————— 52%
#   Running 2020-09-17 (200/365) (7.11 s)  ••••••••••—————————— 55%
#   Running 2020-09-27 (210/365) (7.41 s)  •••••••••••————————— 58%
#   Running 2020-10-07 (220/365) (7.67 s)  ••••••••••••———————— 60%
#   Running 2020-10-17 (230/365) (7.94 s)  ••••••••••••———————— 63%
#   Running 2020-10-27 (240/365) (8.17 s)  •••••••••••••——————— 66%
#   Running 2020-11-06 (250/365) (8.42 s)  •••••••••••••——————— 69%
#   Running 2020-11-16 (260/365) (8.65 s)  ••••••••••••••—————— 71%
#   Running 2020-11-26 (270/365) (8.88 s)  ••••••••••••••—————— 74%
#   Running 2020-12-06 (280/365) (9.12 s)  •••••••••••••••————— 77%
#   Running 2020-12-16 (290/365) (9.34 s)  •••••••••••••••————— 80%
#   Running 2020-12-26 (300/365) (9.55 s)  ••••••••••••••••———— 82%
#   Running 2021-01-05 (310/365) (9.76 s)  ••••••••••••••••———— 85%
#   Running 2021-01-15 (320/365) (9.94 s)  •••••••••••••••••——— 88%
#   Running 2021-01-25 (330/365) (10.11 s)  ••••••••••••••••••—— 90%
#   Running 2021-02-04 (340/365) (10.27 s)  ••••••••••••••••••—— 93%
#   Running 2021-02-14 (350/365) (10.43 s)  •••••••••••••••••••— 96%
#   Running 2021-02-24 (360/365) (10.57 s)  •••••••••••••••••••— 99%
#
# Simulation summary:
#         Summary of pathogen SARS-CoV-2:
#              9,485 cumulative infections
#              2,465 cumulative reinfections
#              9,483 cumulative infectious
#              5,959 cumulative symptomatic cases
#                384 cumulative severe cases
#                103 cumulative critical cases
#              9,444 cumulative recoveries
#                 38 cumulative deaths
#            183,000 cumulative tests
#              5,509 cumulative diagnoses
#                 27 cumulative known deaths
#                  0 cumulative vaccine doses
#                  0 cumulative vaccinated people
#                  0 cumulative diagnoses with custom testing module
#
#         Summary of pathogen Covid 2:
#              7,137 cumulative infections
#                967 cumulative reinfections
#              7,136 cumulative infectious
#              4,669 cumulative symptomatic cases
#                320 cumulative severe cases
#                 72 cumulative critical cases
#              7,099 cumulative recoveries
#                 36 cumulative deaths
#            183,000 cumulative tests
#              4,244 cumulative diagnoses
#                 23 cumulative known deaths
#                  0 cumulative vaccine doses
#                  0 cumulative vaccinated people
#                  0 cumulative diagnoses with custom testing module
#
#                 55 cumulative co-infections
#              9,654 cumulative isolations started
#                  0 cumulative quarantines started

# %%
canada_pop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 canada_pop
#
# NameError: name 'canada_pop' is not defined

# %%
BC_pop.plot_contacts() # plot the contact matrix
#plt.show() # display contact matrix to screen
# Out:
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family ['Roboto Condensed'] not found. Falling back to DejaVu Sans.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.

# %%
canada_pop.plot_contacts()
# Out:
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.
# findfont: Font family 'Roboto Condensed' not found.

# %%
pop = bh.BehaviourModel({'n': 10e3, 'country': 'us'})
# Out:
# Initializing Behaviour Module...
# here is the use_default variable False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pop = bh.BehaviourModel({'n': 10e3, 'country': 'us'})
#
# File ~/Desktop/Mcgill/U3/patho/behaviour/behaviour_model.py:197, in BehaviourModel.__init__(self, pars)
#     194 if pars.as_region == False: # Generate the population separately if doing multi-region simulation,
#     195     # i.e. via regional_behaviour_model.py
#     196     log.debug('Generating a new population...')
# --> 197     self.generate() # updates self.popdict
#     199     # Add summaries post hoc  --- TBD: summaries during generation
#     200     self.compute_information()  # compute full information
#
# File ~/Desktop/Mcgill/U3/patho/behaviour/behaviour_model.py:652, in BehaviourModel.generate(self)
#     644 """
#     645 Actually generate the network.
#     646
#     647 Returns:
#     648     network (dict): A dictionary of the full population with ages, connections, and other attributes.
#     649 """
#     650 log.debug('generate()')
# --> 652 self.load_pars_and_data() # Updates self.pars
#     654 self.make_structures() # Updates self.structs
#     656 # spcnx.make_all_contacts(self, self.structs, self.pars) # Updates self.popdict
#
# File ~/Desktop/Mcgill/U3/patho/behaviour/behaviour_model.py:345, in BehaviourModel.load_pars_and_data(self)
#     341 self.cm_age_by_brackets = pars.cm_age_by_brackets
#     343 if self.input_pars.init_incomes_and_watches:
#     344     # Load the age-income table.
# --> 345     age_income_raw = spdata.get_age_income_dist(**pars.loc_pars)
#     347     # Process it. (Increase the resolution). ai stands for age-income table.
#     348     pars.age_income_dist, pars.ai_age_bracs, pars.ai_inc_bracs = spdata.process_age_income_dist(age_income_raw, pars.location, pars.state_location, pars.country_location)
#
# File ~/Desktop/Mcgill/U3/patho/behaviour/data_distributions.py:465, in get_age_income_dist(datadir, location, state_location, country_location, use_default)
#     462 file_path = os.path.join(file_path, fname)
#     464 # Load data
# --> 465 data = pd.read_csv(file_path + '.csv', header=None)
#     467 # Return values as a 2d array.
#     468 return data.values
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/io/parsers/readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1216, in TextFileReader._make_engine(self, f, engine)
#    1212     mode = "rb"
#    1213 # error: No overload variant of "get_handle" matches argument types
#    1214 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216 self.handles = get_handle(  # type: ignore[call-overload]
#    1217     f,
#    1218     mode,
#    1219     encoding=self.options.get("encoding", None),
#    1220     compression=self.options.get("compression", None),
#    1221     memory_map=self.options.get("memory_map", False),
#    1222     is_text=is_text,
#    1223     errors=self.options.get("encoding_errors", "strict"),
#    1224     storage_options=self.options.get("storage_options", None),
#    1225 )
#    1226 assert self.handles is not None
#    1227 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/pathosim/lib/python3.8/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tian/Desktop/Mcgill/U3/patho/behaviour/data/income_age_dists/usa-Washington-seattle_metro.csv'

# %%
"""
Make a population using synthpops for a specified location different from the
default location (seattle_metro).
"""
import synthpops as sp
import matplotlib.pyplot as plt

pars = dict(
    n                 = 10e3,
    rand_seed         = 123,
    location          = 'Spokane_County',
    state_location    = 'Washington',
    country_location  = 'usa',
    smooth_ages       = 1,
    household_method  = 'fixed_ages',
)


pop = sp.Pop(**pars)  # generate contact network
# Out:
# ========== setting country location = usa

# %%
pop.plot_contacts()
